# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

data_frame = pd.read_csv("../HACKATHON DATASET/dataset 1_x.csv")
data_frame1 = pd.read_csv("../HACKATHON DATASET/dataset 1_y.csv")
data_frame2 = pd.read_csv("../HACKATHON DATASET/dataset 1_z.csv")

# %%
print(data_frame)
# Out:
#             Time  19/03/2021  20/03/2021  21/03/2021  22/03/2021  23/03/2021  \
# 0    12:01:43 AM   -0.000305   -0.000262   -0.000247   -0.000188   -0.000344
# 1    12:06:43 AM   -0.000266   -0.000305   -0.000298   -0.000255   -0.000220
# 2    12:11:39 AM   -0.000309   -0.000247   -0.000294   -0.000286   -0.000278
# 3    12:16:40 AM   -0.000223   -0.000220   -0.000270   -0.000282   -0.000325
# 4    12:21:40 AM   -0.000188    0.000319   -0.000208    0.000206   -0.000239
# ..           ...         ...         ...         ...         ...         ...
# 283  11:36:58 PM    0.000194   -0.000235   -0.000278   -0.000274   -0.000340
# 284  11:41:58 PM    0.000311   -0.000266   -0.000282   -0.000301   -0.000200
# 285  11:46:54 PM    0.000198   -0.000270   -0.000286   -0.000337   -0.000231
# 286  11:51:58 PM    0.000229   -0.000266   -0.000305   -0.000270   -0.000247
# 287  11:56:54 PM   -0.000243   -0.000282   -0.000216   -0.000309   -0.000239
#
#      24/03/2021  25/03/2021
# ...

# %%
dfTime = pd.DataFrame(data_frame,columns=["Time"])
dfDate1x = pd.DataFrame(data_frame,columns=["19/03/2021"]) 
dfDate1y = pd.DataFrame(data_frame1,columns=["19/03/2021"]) 
dfDate1z = pd.DataFrame(data_frame2,columns=["19/03/2021"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\bartolome\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\users\bartolome\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\bartolome\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# ...

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('../HACKATHON DATASET/dataset 1_x.csv','r') as csvfile:
    lines = csv.reader(csvfile, delimiter=',')
    for row in lines:
            x.append(row[0])
            y.append((row[1]))
            
plt.plot(x, y, color = 'g',marker = 'o', label = "X")

x = []
y = []

with open('../HACKATHON DATASET/dataset 1_y.csv','r') as csvfile:
    lines = csv.reader(csvfile, delimiter=',')
    for row in lines:
            x.append(row[0])
            y.append((row[1]))
plt.plot(x, y, color = 'r',marker = 'o', label = "Y")     

x = []
y = []

with open('../HACKATHON DATASET/dataset 1_z.csv','r') as csvfile:
    lines = csv.reader(csvfile, delimiter=',')
    for row in lines:
            x.append(row[0])
            y.append((row[1]))
plt.plot(x, y, color = 'b',marker = 'o', label = "Z") 

plt.xlabel('Specific Time')
plt.ylabel('Acceleration')
plt.title('07/19/2021', fontsize = 20)
plt.legend()
plt.show()

# %%
dfDate1x = pd.DataFrame(data_frame,columns=['Time','19/03/2021']) 
dfDate1y = pd.DataFrame(data_frame1,columns=['Time','19/03/2021']) 
dfDate1z = pd.DataFrame(data_frame2,columns=['Time','19/03/2021'])

x=['Time']
y=['19/03/2021']

plt.plot(x,y , color = 'b',marker = 'o', label = "X") 

plt.xlabel('Specific Time')
plt.ylabel('Acceleration')
plt.title('07/19/2021', fontsize = 20)
plt.legend()
plt.show()
